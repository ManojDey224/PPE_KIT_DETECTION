# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.0/882.0 kB 15.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.__version__
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# '8.3.6'

# %%
from ultralytics import YOLOWorld

# Initialize a YOLO-World model
model = YOLOWorld('yolov8l-world.pt')  # or select yolov8m/l-world.pt for different sizes

# Execute inference with the YOLOv8s-world model on the specified image
results = model.predict('a.jpg', device='cpu', save=True)

# Show results
results[0].show()
# Out:
# image 1/1 /content/a.jpg: 384x640 2 persons, 2 tvs, 1 book, 3101.6ms
# Speed: 7.4ms preprocess, 3101.6ms inference, 22.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=640x360>

# %%
# Define custom classes
model.set_classes(["hard hat", "gloves"])

# Execute prediction for specified categories on an image
results = model.predict('a.jpg', device='cpu', save=True)

# Show results
results[0].show()
# Out:
# requirements: Ultralytics requirement ['git+https://github.com/ultralytics/CLIP.git'] not found, attempting AutoUpdate...
# ...
#   Cloning https://github.com/ultralytics/CLIP.git to /tmp/pip-req-build-0kjkaabc
#   Resolved https://github.com/ultralytics/CLIP.git to commit f8cd7eec0bf1dc35cca8c090e7764b88027c3039
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 69.0 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1382219 sha256=a4678cce7518e795f70d2186a6ab4bfb36aa8504f91ba6ba248eed9fd606b6d7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qyq0mts8/wheels/2e/25/92/e26f2a227599930e19a8188891e9600b6dd36721a0f8d6ef40
# Successfully built clip
# ...
#
# requirements: AutoUpdate success ✅ 11.3s, installed 1 package: ['git+https://github.com/ultralytics/CLIP.git']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# ...

# %%
from ultralytics import YOLO

# Initialize a YOLO-World model
model = YOLO('yolov8l-world.pt')

model.set_classes(["hard hat", "gloves", "safety glasses"])

# Save the model with the defined offline vocabulary
model.save("custom_yolov8l.pt")

# %%
from ultralytics import YOLO

# Load your custom model
model = YOLO('custom_yolov8l.pt')


# Run inference to detect your custom classes
results = model.predict('/content/input.mp4', device='cpu', save=True)

# Show results
results[0].show()
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/487) /content/input.mp4: 384x640 4 glovess, 2211.6ms
# video 1/1 (frame 2/487) /content/input.mp4: 384x640 4 glovess, 1888.6ms
# video 1/1 (frame 3/487) /content/input.mp4: 384x640 4 glovess, 1898.5ms
# video 1/1 (frame 4/487) /content/input.mp4: 384x640 5 glovess, 1908.8ms
# video 1/1 (frame 5/487) /content/input.mp4: 384x640 4 glovess, 1891.9ms
# ...
